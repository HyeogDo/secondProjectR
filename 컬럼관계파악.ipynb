# %%
library(readxl)
library(stringr)
library(dplyr)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
data <- read.csv("./withoutOutlier.csv", fileEncoding = "utf-8")

# %%
nrow(data)
# Out:
# [1] 193

# %%
str_length(data$감독[1])
# Out:
# [1] 3

# %%
length(data$감독)
for (i in 1:nrow(data)) {
    if(str_length(data$감독[i]) == 1) {
        print(i)
    }
}
# Out:
# [1] 193
# [1] 100
# [1] 180

# %%
data$감독[100]
data$감독[180]
# Out:
# [1] 백
# 128 Levels: 강대규 강우석 강윤성 강제규 강형철 곽경택 곽경택,안권태 ... 황인호
# [1] 창
# 128 Levels: 강대규 강우석 강윤성 강제규 강형철 곽경택 곽경택,안권태 ... 황인호

# %%
data
# Out:
#     영화명                     누적매출액  누적관객수 스크린수 상영횟수
# 1   1987                       58169776145 7232387    1299     138226
# 2   1번가의 기적               15494122100 2535450     340      54566
# 3   26년                       21242367145 2963652     611      50679
# 4   7광구                      19391653500 2242510     812      47346
# 5   7급 공무원                 26380710000 4039891     475      90779
# 6   82년생 김지영              30298542310 3678156    1486     145441
# 7   가문의 부활 - 가문의 영광3 15996330400 2598859     444      51434
# 8   가문의 영광4 - 가문의 수난 17792219500 2368267     537      48432
# 9   가문의 위기(가문의 영광2)  28622355500 4529876     351      61009
# 10  가장 보통의 연애           24885803430 2924563    1073     111527
# 11  감기                       21774884000 3117859     806      55046
# 12  감시자들                   39380162179 5508017     949     100309
# 13  강남 1970                  17718699499 2192276     841      53304
# 14  강철비                     35490346466 4452850    1426      80359
# ...

# %%
plot(data$누적매출액, data$누적관객수)
# Out:
# plot without title

# %%
plot(data$스크린수, data$누적관객수)
# Out:
# plot without title

# %%
cor(data$스크린수, data$누적관객수)
# Out:
# [1] 0.422587

# %%
plot(data$상영횟수, data$누적관객수)
# Out:
# plot without title

# %%
cor(data$상영횟수, data$누적관객수)
# Out:
# [1] 0.8155328

# %%
cor(data$스크린수, data$상영횟수)
# Out:
# [1] 0.6491068

# %%
hist(data$스크린수)
# Out:
# Plot with title "Histogram of data$스크린수"

# %%
hist(data$누적관객수)
# Out:
# Plot with title "Histogram of data$누적관객수"

# %%
hist(data$상영횟수)
# Out:
# Plot with title "Histogram of data$상영횟수"

# %%
boxplot(data$누적관객수)
# Out:
# plot without title

# %%
boxplot(data$스크린수)
# Out:
# plot without title

# %%
boxplot(data$상영횟수)
# Out:
# plot without title

# %%
plot(arrange(data, 스크린수)$스크린수)
# Out:
# plot without title

# %%
ndata <- subset(subset(data, 누적관객수 > 3000000), select=c(누적관객수))

# %%
nrow(ndata)
# Out:
# [1] 109

# %%
kmeans(ndata,3, iter.max = 100)
# Out:
# K-means clustering with 3 clusters of sizes 43, 37, 29
#
# Cluster means:
#   누적관객수
# 1    3575761
# 2    5273662
# 3    7735577
#
# Clustering vector:
#   1   5   6   9  11  12  14  15  16  17  18  19  21  23  24  25  26  27  29  30
#   3   1   1   2   1   2   2   1   1   1   3   2   3   1   2   3   3   3   3   1
#  31  32  35  36  40  42  43  44  46  49  51  56  58  59  60  61  62  63  64  65
#   2   3   1   1   3   1   1   2   1   2   3   3   1   2   2   2   2   2   1   3
#  67  68  71  75  80  82  83  85  91  92  93  94  96  99 103 108 111 112 113 114
#   3   1   3   1   2   3   2   1   2   3   2   3   2   1   2   3   3   2   1   1
# 118 119 120 122 123 124 126 127 129 130 131 132 133 134 135 136 137 138 139 140
#   1   2   1   1   3   1   1   2   1   2   1   3   1   2   2   1   2   2   1   1
# 142 144 147 148 150 152 153 154 157 161 163 164 166 167 168 169 170 173 175 176
#   2   3   2   1   3   2   2   1   3   2   3   2   1   1   2   2   1   1   1   3
# ...

# %%
kmeanData <- kmeans(ndata,3)

# %%
ndata2 <- cbind(ndata,kdata=kmeanData$cluster)

# %%
table(ndata2$kdata)
# Out:
#  1  2  3
# 37 29 43

# %%
plot(ndata2$kdata,ndata2$누적관객수)
# Out:
# plot without title

# %%
test <- subset(data, 누적관객수 > 3000000)

# %%
nrow(test)
# Out:
# [1] 109

# %%
boxplot(test$누적관객수)
# Out:
# plot without title

# %%
kdata <- kmeans(subset(test, select=c(스크린수, 상영횟수)), 3)

# %%
table(kdata$cluster)
# Out:
#  1  2  3
# 26 38 45
