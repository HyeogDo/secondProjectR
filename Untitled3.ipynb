# %%
library(e1071)
library(dplyr)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
data <- read.csv("./진짜진짜최종데이터셋.csv", fileEncoding = "utf-8")

# %%
data
# Out:
#     cluster 배급사점수 장르점수 감독_배우시너지점수 주연점수  감독점수
# 1   1       2          10       3                    4.000000 2.000000
# 2   1       2          10       8                    8.250000 4.000000
# 3   1       1          10       0                    4.000000 3.000000
# 4   1       3          10       3                    6.777778 2.714286
# 5   1       3          10       0                    7.666667 2.500000
# 6   1       2          20       6                    6.500000 4.000000
# 7   1       1          10       1                    6.777778 2.714286
# 8   1       3          10       5                   11.750000 2.500000
# 9   1       1          10       7                    4.000000 4.000000
# 10  1       3          10       4                   11.375000 4.000000
# 11  1       3          10       7                    8.000000 4.000000
# 12  1       3          20       6                    6.700000 4.800000
# 13  1       3          20       6                   11.375000 4.500000
# ...

# %%
test <- readRDS("./최종SVM_Model_2.rds")

# %%
test_d <- data[90,]

# %%
for ( i in 1:600) {
    test_d$개봉일스크린수 <- i
    print(predict(test,test_d))
}
# Out:
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# Levels: 1 2 3
# 90
#  3
# ...

# %%
distributor <- read.csv("./distributor_forgraph.csv", fileEncoding = "utf-8")

# %%
genre <- read.csv("./genre_forgraph.csv", fileEncoding = "utf-8")

# %%
distributor$배급사_평균누적관객수 <- distributor$누적관객수합 / distributor$횟수

# %%
distributor
# Out:
#   배급사                          횟수 누적관객수합 배급사_평균누적관객수
# 1 CJ ENM                          42   226147824    5384472
# 2 (주)쇼박스                      29   156775745    5406060
# 3 (주)넥스트엔터테인먼트월드(NEW) 14    65733469    4695248
# 4 (주)롯데엔터테인먼트            14    72799502    5199964
# 5 기타                             9    41673129    4630348

# %%
options(scipen = 100)

# %%
barplot(distributor$횟수,
        names=c("CJ ENM", "쇼박스", "넥스트", "롯데", "기타"),
        cex.names = 0.7,
        col= rainbow(nrow(distributor)),
        ylim = c(0,50)
       
       )
legend(4,40, distributor$배급사,
       cex = 0.7,
       fill = rainbow(nrow(distributor))
    
)
# Out:
# plot without title

# %%
barplot(distributor$누적관객수합,
        names=c("CJ ENM", "쇼박스", "넥스트", "롯데", "기타"),
        cex.names = 0.7,
        col= rainbow(nrow(distributor)),
        ylim = c(0,250000000)
       
       )
legend(4,200000000, distributor$배급사,
       cex = 0.7,
       fill = rainbow(nrow(distributor))
    
)
# Out:
# plot without title

# %%
barplot(distributor$배급사_평균누적관객수,
        names=c("CJ ENM", "쇼박스", "넥스트", "롯데", "기타"),
        cex.names = 0.7,
        col= rainbow(nrow(distributor)),
        ylim = c(0,7000000)
       
       )
legend(4,6800000, distributor$배급사,
       cex = 0.7,
       fill = rainbow(nrow(distributor))
    
)
# Out:
# plot without title

# %%
genre <- arrange(genre,desc(빈도수)); genre
# Out:
#    장르           누적관객수 빈도수
# 1  드라마         160733979  33
# 2  코미디          79566549  17
# 3  범죄            82285716  16
# 4  액션            84409628  14
# 5  사극            58756875  11
# 6  멜로/로맨스     16847559   3
# 7  미스터리        15511995   3
# 8  스릴러          13012318   3
# 9  공포(호러)       7525189   2
# 10 어드벤처        14956710   2
# 11 전쟁            13486983   2
# 12 SF               9350323   1
# 13 서부극(웨스턴)   6685845   1
